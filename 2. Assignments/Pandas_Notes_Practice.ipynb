# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\DataScience-GenerativeAI-AgenticAI\Practical\DS-GenAi-AgenticAI-Bootcamp\6-month-AI-Roadmap_2025\6. Shared\data.csv")
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
data={'a':100,'b':200,'c':300,'d':400}
series_data=pd.Series(data)
type(series_data)
# Out:
# pandas.core.series.Series

# %%
series_data=pd.Series(df['CountryName'])
series_data[0]
# Out:
# 'Aruba'

# %%
type(series_data)
# Out:
# pandas.core.series.Series

# %%
df.shape
df.columns
df.index
df.dtypes
print(df.describe())
print(df.columns)
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.rename(columns={'CountryName':'Country Name'},inplace=True)

# %%
df
# Out:
#              Country Name CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.isnull().sum()
# Out:
# Country Name     0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.iloc[0]
# Out:
# Country Name           Aruba
# CountryCode              ABW
# BirthRate             10.244
# InternetUsers           78.9
# IncomeGroup      High income
# Name: 0, dtype: object

# %%
df.iloc[1,2]
# Out:
# np.float64(35.253)

# %%
df.iloc[0:3, 1:3]
# Out:
#   CountryCode  BirthRate
# 0         ABW     10.244
# 1         AFG     35.253
# 2         AGO     45.985

# %%
df.loc[3, 'CountryCode']
# Out:
# 'ALB'

# %%
df.loc[0:3, ['CountryCode','BirthRate']]
# Out:
#   CountryCode  BirthRate
# 0         ABW     10.244
# 1         AFG     35.253
# 2         AGO     45.985
# 3         ALB     12.877

# %%
df[df['BirthRate']>10]
# Out:
#              Country Name CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.sort_index(ascending=False)
# Out:
#              Country Name CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df.sort_values('BirthRate',ascending=False)
# Out:
#              Country Name CountryCode  BirthRate  InternetUsers  \
# 127                 Niger         NER     49.661         1.7000
# 2                  Angola         AGO     45.985        19.1000
# 167                  Chad         TCD     45.745         2.3000
# 11                Burundi         BDI     44.151         1.3000
# 115                  Mali         MLI     44.138         3.5000
# ..                    ...         ...        ...            ...
# 68                 Greece         GRC      8.500        59.8663
# 86                  Italy         ITA      8.500        58.4593
# 89                  Japan         JPN      8.200        89.7100
# 74   Hong Kong SAR, China         HKG      7.900        74.2000
# 142              Portugal         PRT      7.900        62.0956
#
#              IncomeGroup
# 127           Low income
# 2    Upper middle income
# 167           Low income
# 11            Low income
# 115           Low income
# ..                   ...
# ...

# %%
df.groupby('CountryCode')['InternetUsers'].sum()
# Out:
# CountryCode
# ABW    78.9
# AFG     5.9
# AGO    19.1
# ALB    57.2
# ARE    88.0
#        ...
# WSM    15.3
# YEM    20.0
# ZAF    46.5
# ZMB    15.4
# ZWE    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
a=[{
    'Name':'John',
    'Surname':'Willson'
}]
b=[{
    'Age':23,
    'Address':'UK'
}]

a=pd.DataFrame(a)
b=pd.DataFrame(b)
pd.concat([a,b],axis=1)
# Out:
#    Name  Surname  Age Address
# 0  John  Willson   23      UK

# %%
a=[{
    'Id':1,
    'Name':'John',
    'Surname':'Willson'
}]
b=[{
    'Id':1,
    'Age':23,
    'Address':'UK'
}]
c=[{
    'Id':1,
    'National':'India',
    'Postal Code':'0056'
}]

a=pd.DataFrame(a)
b=pd.DataFrame(b)
c=pd.DataFrame(c)
newFame=pd.concat([a,b,c],axis=1)
newFame
# Out:
#    Id  Name  Surname  Id  Age Address  Id National Postal Code
# 0   1  John  Willson   1   23      UK   1    India        0056

# %%
df.drop(columns=['IncomeGroup'],axis=0)
# Out:
#              Country Name CountryCode  BirthRate  InternetUsers
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
# [195 rows x 4 columns]

# %%
df
# Out:
#              Country Name CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.to_numpy()
# Out:
# array([['Aruba', 'ABW', 10.244, 78.9, 'High income'],
#        ['Afghanistan', 'AFG', 35.253, 5.9, 'Low income'],
#        ['Angola', 'AGO', 45.985, 19.1, 'Upper middle income'],
#        ['Albania', 'ALB', 12.877, 57.2, 'Upper middle income'],
#        ['United Arab Emirates', 'ARE', 11.044, 88.0, 'High income'],
#        ['Argentina', 'ARG', 17.716, 59.9, 'High income'],
#        ['Armenia', 'ARM', 13.308, 41.9, 'Lower middle income'],
#        ['Antigua and Barbuda', 'ATG', 16.447, 63.4, 'High income'],
#        ['Australia', 'AUS', 13.2, 83.0, 'High income'],
#        ['Austria', 'AUT', 9.4, 80.6188, 'High income'],
#        ['Azerbaijan', 'AZE', 18.3, 58.7, 'Upper middle income'],
#        ['Burundi', 'BDI', 44.151, 1.3, 'Low income'],
#        ['Belgium', 'BEL', 11.2, 82.1702, 'High income'],
#        ['Benin', 'BEN', 36.44, 4.9, 'Low income'],
#        ['Burkina Faso', 'BFA', 40.551, 9.1, 'Low income'],
#        ['Bangladesh', 'BGD', 20.142, 6.63, 'Lower middle income'],
# ...

# %%
df.iloc[0,2]
# Out:
# np.float64(10.244)

# %%
#How to reset the index in a Python Pandas DataFrame? 
student_dict = {'Name': ['Kate', 'Harry', 'Sheila'], 'Age': [10, 11, 12], 
'Marks': [85, 77, 91]}

# %%
df=pd.DataFrame(student_dict)
df
# Out:
#      Name  Age  Marks
# 0    Kate   10     85
# 1   Harry   11     77
# 2  Sheila   12     91

# %%
student_df = df.reset_index(drop=True) 
print(student_df)
# Out:
#      Name  Age  Marks
# 0    Kate   10     85
# 1   Harry   11     77
# 2  Sheila   12     91

# %%
#How to rename index
student_df.index.names=['Id']
student_df
# Out:
#       Name  Age  Marks
# Id
# 0     Kate   10     85
# 1    Harry   11     77
# 2   Sheila   12     91

# %%
#How to get frequency count of unique items in a Pandas DataFrame?
s = pd.Series(data = [1,2,3,4,3,5,3,7,1])
print(s.value_counts())
# Out:
# 3    3
# 1    2
# 2    1
# 4    1
# 5    1
# 7    1
# Name: count, dtype: int64

# %%
# student_df.drop(0)
student_df
# Out:
#       Name  Age  Marks
# Id
# 0     Kate   10     85
# 1    Harry   11     77
# 2   Sheila   12     91

# %%
pd.Timedelta(days=20,hours=12,minutes=30,seconds=1,microseconds=1)
# Out:
# Timedelta('20 days 12:30:01.000001')

# %%
address=['UK','Dubai','USA']

# %%
# student_df.insert(0,'Address',address,True)
student_df.drop(1,axis=0,inplace=True)
student_df
# Out:
#    Address Address Address Address Address Address    Name  Age  Marks
# Id
# 0       UK      UK      UK      UK     NaN     NaN    Kate   10     85
# 2      USA     USA     USA     USA     NaN     NaN  Sheila   12     91
