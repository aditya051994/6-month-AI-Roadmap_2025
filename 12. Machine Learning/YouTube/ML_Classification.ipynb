# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\DataScience-GenerativeAI-AgenticAI\Practical\DS-GenAi-AgenticAI-Bootcamp\6-month-AI-Roadmap_2025\6. Shared\Social_Network_Ads.csv')
df.drop(columns=['User ID','Gender','EstimatedSalary'],inplace=True)

# %%
sns.scatterplot(data=df,x='Age',y='Purchased')
plt.show()

# %%
df.isnull().sum()
# Out:
# Age          0
# Purchased    0
# dtype: int64

# %%
#pip install scikit-learn

# %%
x=df[['Age']]
y=df['Purchased']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
LR.score(X_test,Y_test)
# Out:
# 0.9125

# %%
LR.predict([[45]])
# Out:
# c:\Users\a864911\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
sns.scatterplot(data=df,x='Age',y='Purchased')
sns.lineplot(x='Age',y=LR.predict(x),data=df,color='red')
plt.show()

# %%
#Multiple Logestic Regression

# %%
df=pd.read_csv(r'C:\DataScience-GenerativeAI-AgenticAI\Practical\DS-GenAi-AgenticAI-Bootcamp\6-month-AI-Roadmap_2025\6. Shared\placement_Classification.csv')
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
#We analysis here by x and y
sns.scatterplot(data=df,x='cgpa',y='resume_score',hue='placed')
plt.show()

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
x=df.iloc[:,:2]
y=df.iloc[:,-1]
y.ndim
# Out:
# 1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
LR.score(X_test,Y_test)
# Out:
# 0.95

# %%
LR.predict([[8.27,8.8]])
# Out:
# c:\Users\a864911\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
#To find decision line we are using mlxtend
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=LR)
plt.show()
# Out:
# c:\Users\a864911\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
LR.coef_
# Out:
# array([[3.14723985, 0.33250211]])

# %%
LR.intercept_
# Out:
# array([-23.72006539])

# %%
##Multiclass Logestic Classification
df=pd.read_csv(r'C:\DataScience-GenerativeAI-AgenticAI\Practical\DS-GenAi-AgenticAI-Bootcamp\6-month-AI-Roadmap_2025\6. Shared\Iris.csv')
df.drop(columns=['Id'],inplace=True)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris=pd.read_csv(r'C:\DataScience-GenerativeAI-AgenticAI\Practical\DS-GenAi-AgenticAI-Bootcamp\6-month-AI-Roadmap_2025\6. Shared\Iris.csv')
iris.drop(columns=['Id'],inplace=True)

# %%
sns.pairplot(data=iris,hue='Species')
plt.show()

# %%
#SepalWidth Collapse and we can not find and predection
iris
x=iris.iloc[:,:-1]
y=iris.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
#OVR - One vs Rest
LR=LogisticRegression(multi_class='ovr')
LR.fit(X_train,Y_train)
# Out:
# c:\Users\a864911\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='ovr')

# %%
LR.score(X_test,Y_test)
# Out:
# 0.9666666666666667

# %%
#MultiClass
LR1=LogisticRegression(multi_class='multinomial')
LR1.fit(X_train,Y_train)
# Out:
# c:\Users\a864911\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='multinomial')

# %%
LR.score(X_test,Y_test)
# Out:
# 0.9666666666666667

# %%
sns.scatterplot
# Out:
# <function seaborn.relational.scatterplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, legend='auto', ax=None, **kwargs)>

# %%
#Confusion Matrix
df=pd.read_csv(r'C:\DataScience-GenerativeAI-AgenticAI\Practical\DS-GenAi-AgenticAI-Bootcamp\6-month-AI-Roadmap_2025\6. Shared\placement_Classification.csv')
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
#      ..
# 95    0
# 96    1
# 97    0
# 98    1
# 99    0
# Name: placed, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
LR.score(X_test,Y_test)
# Out:
# 0.95

# %%
#confusion <Matrxi
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score
CM=confusion_matrix(Y_test,LR.predict(X_test))

# %%
sns.heatmap(CM,annot=True)
plt.show()

# %%
precision_score(Y_test,LR.predict(X_test))*100
# Out:
# 100.0

# %%
recall_score(Y_test,LR.predict(X_test))*100
# Out:
# 88.88888888888889

# %%
f1_score(Y_test,LR.predict(X_test))*100
# Out:
# 94.11764705882352

# %%
#Imbalanced Dataset

# %%
df=pd.read_csv(r'C:\DataScience-GenerativeAI-AgenticAI\Practical\DS-GenAi-AgenticAI-Bootcamp\6-month-AI-Roadmap_2025\6. Shared\Social_Network_Ads.csv')
df.drop(columns=['User ID','Gender'],inplace=True)
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df['Purchased'].value_counts() # data in imbalanced
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64
