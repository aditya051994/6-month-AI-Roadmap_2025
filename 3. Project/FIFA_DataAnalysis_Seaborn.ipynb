# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#get data fro m dataFrame
fifa_df=pd.read_csv(r"C:\DataScience-GenerativeAI-AgenticAI\Practical\DS-GenAi-AgenticAI-Bootcamp\6-month-AI-Roadmap_2025\6. Shared\FIFA.csv").head(50)
fifa_df
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Understand Data
fifa_df.describe()
# Out:
#        Unnamed: 0             ID        Age    Overall  Potential  \
# count    50.00000      50.000000  50.000000  50.000000  50.000000
# mean     24.50000  179530.760000  28.400000  88.940000  90.040000
# std      14.57738   38834.538666   3.458205   1.671001   1.999592
# min       0.00000    1179.000000  19.000000  87.000000  87.000000
# 25%      12.25000  174443.250000  26.000000  88.000000  88.250000
# 50%      24.50000  189421.500000  28.000000  88.500000  90.000000
# 75%      36.75000  197301.750000  31.000000  90.000000  91.000000
# max      49.00000  231747.000000  40.000000  94.000000  95.000000
#
#            Special  International Reputation  Weak Foot  Skill Moves  \
# count    50.000000                 50.000000  50.000000    50.000000
# mean   1986.080000                  3.660000   3.420000     3.060000
# std     322.230038                  0.658074   0.835195     1.300078
# min    1262.000000                  3.000000   1.000000     1.000000
# ...

# %%
fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                50 non-null     int64
#  1   ID                        50 non-null     int64
#  2   Name                      50 non-null     object
#  3   Age                       50 non-null     int64
#  4   Photo                     50 non-null     object
#  5   Nationality               50 non-null     object
#  6   Flag                      50 non-null     object
#  7   Overall                   50 non-null     int64
#  8   Potential                 50 non-null     int64
#  9   Club                      50 non-null     object
#  10  Club Logo                 50 non-null     object
#  11  Value                     50 non-null     object
#  12  Wage                      50 non-null     object
#  13  Special                   50 non-null     int64
# ...

# %%
#Size of dataframe
fifa_df.shape
# Out:
# (50, 89)

# %%
fifa_df['Body Type'].value_counts()
# Out:
# Body Type
# Normal                 31
# Lean                   12
# Stocky                  2
# Messi                   1
# Neymar                  1
# C. Ronaldo              1
# Courtois                1
# PLAYER_BODY_TYPE_25     1
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa_df['Age']
ax = sns.distplot(x, bins=10)
plt.show()

# %%
#Comment
#It can be seen that the Age variable is slightly positively skewed.

# %%
fig,ax=plt.subplots(figsize=(8,6))
x=fifa_df['Age']
ax=sns.distplot(x,bins=10,vertical=True)

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa_df['Age']
x = pd.Series(x, name="Age variable")
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa_df['Age']
x = pd.Series(x, name="Age variable")
ax = sns.kdeplot(x,color='r',shade=True)
plt.show()

# %%
sns.distplot(fifa_df['Age'],bins=10)
plt.grid()

# %%
sns.distplot(fifa_df['Age'],bins=10,hist=False)
plt.grid()

# %%
#Explore Preferred Foot variable

# %%
fifa_df['Preferred Foot'].unique()
# Out:
# array(['Left', 'Right'], dtype=object)

# %%
fifa_df['Preferred Foot'].nunique()
# Out:
# 2

# %%
fifa_df['Preferred Foot'].value_counts()
# Out:
# Preferred Foot
# Right    36
# Left     14
# Name: count, dtype: int64

# %%
print('Missing vlaue for Preferred Foot: ',fifa_df['Preferred Foot'].isnull().sum())
# Out:
# Missing vlaue for Preferred Foot:  0

# %%
#Visualize distribution of values with Seaborn countplot() function.
f,ax=plt.subplots(figsize=(5,5))
sns.countplot(x='Preferred Foot',data=fifa_df,color='c')
plt.grid()

# %%
#Visualize distribution of values with Seaborn countplot() function.
f,ax=plt.subplots(figsize=(5,5))
sns.countplot(x='Preferred Foot',hue='Real Face',data=fifa_df,color='c')
plt.grid()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.countplot(y="Preferred Foot", data=fifa_df, color="c")
plt.show()

# %%
#Seaborn Catplot() function

# %%
g = sns.catplot(x="Preferred Foot", kind="count", data=fifa_df,palette="ch:.25")

# %%
#International Reputation
fifa_df['International Reputation'].unique()
# Out:
# array([5., 4., 3.])

# %%
fifa_df['International Reputation'].value_counts()
# Out:
# International Reputation
# 4.0    23
# 3.0    22
# 5.0     5
# Name: count, dtype: int64

# %%
sns.stripplot(x='International Reputation',data=fifa_df,y="Potential")
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
sns.stripplot(x='International Reputation',data=fifa_df,y="Potential",jitter=0.01)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=fifa_df["Potential"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=fifa_df['International Reputation'],y=fifa_df["Potential"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x=fifa_df["Potential"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", data=fifa_df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential",hue='Preferred Foot', data=fifa_df)
plt.show()

# %%
fifa_df[['International Reputation','Potential']]
# Out:
#     International Reputation  Potential
# 0                        5.0         94
# 1                        5.0         94
# 2                        5.0         93
# 3                        4.0         93
# 4                        4.0         92
# 5                        4.0         91
# 6                        4.0         91
# 7                        5.0         91
# 8                        4.0         91
# 9                        3.0         93
# 10                       4.0         90
# 11                       4.0         90
# 12                       3.0         90
# 13                       4.0         90
# 14                       3.0         90
# 15                       3.0         94
# 16                       3.0         91
# 17                       4.0         90
# 18                       3.0         92
# 19                       4.0         90
# 20                       4.0         89
# 21                       4.0         89
# ...

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa_df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa_df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa_df, capsize=0.2)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.lineplot(x="Stamina", y="Strength", data=fifa_df)
plt.show()

# %%
sns.lineplot(x='Age',y='Potential',data=fifa_df,hue='Preferred Foot')
# Out:
# <Axes: xlabel='Age', ylabel='Potential'>

# %%
sns.lmplot(x="Overall", y="Potential", col="Preferred Foot", data=fifa_df, col_wrap=2, height=5, aspect=1)
